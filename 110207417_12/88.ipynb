# %%
import csv
import random

f=[]
b=[]
c=[]
d=[]
e=[]

file = open('names.csv')

for lines in  file:

    line = lines.split(",")
    
    
    b.append(line[0])
    b.append(line[1])
    c.append(line[2])
    
    
    
 
out_file = '110207417_data.csv'
fout = open (out_file, 'w')
scorelist=[]


for i in range(150):
    
    lastname=random.choice(b)
    
    firstname=random.choice(c)
    
    full_name='{}, {}'.format(lastname, firstname)


    
    i+=1
    

    
    j=random.randint(3,8)
    
    for k in range(j) :
        p=random.randint(1,4)
        s=random.randint(0, 100)
        score=' {}, {}'.format(p, s)
        scorelist.append(score)
        scorelist_str = ','.join(scorelist)
    fout.write('{}, {}'.format(full_name, scorelist_str))
    final='{},{}\n'.format(full_name, scorelist_str)
    print (final)
    
    scorelist=[]
# Out:
# Alice, Hall
# , 1, 91, 4, 11, 3, 53, 4, 54, 1, 24, 4, 34, 1, 31
#
# Mia, Alvarez
# , 4, 0, 2, 78, 3, 81, 4, 46, 1, 96
#
# Charles, Morgan
# , 3, 40, 2, 21, 1, 59
#
# Ronnie, Alvarez
# , 4, 1, 4, 13, 3, 73, 3, 92, 4, 84
#
# Oscar, Jimenez
# , 2, 17, 2, 61, 1, 57, 1, 2
#
# Ada, Smith
# , 2, 62, 3, 79, 4, 72, 4, 47, 2, 53, 4, 19, 4, 26, 4, 96
#
# Deliah, Green
# , 2, 95, 2, 34, 2, 67, 2, 51, 1, 85, 4, 88
#
# David, Bennet
# , 4, 19, 2, 23, 3, 92, 2, 100, 2, 75, 3, 69, 4, 24, 4, 39
#
# Edith, Patel
# , 2, 5, 3, 40, 3, 92
#
# Arlo, Adams
# , 3, 95, 3, 49, 2, 76, 3, 25, 4, 24, 4, 80, 3, 20
#
# Stanley, Lopez
# , 2, 75, 1, 97, 3, 55, 3, 92, 4, 89, 3, 78, 4, 11
#
# Leo, Reed
# , 2, 5, 3, 39, 3, 39, 4, 77, 1, 100, 3, 10, 2, 75
#
# Amber, Jones
# , 1, 29, 4, 61, 4, 42
#
# Orla, Smith
# , 2, 95, 1, 89, 3, 79, 3, 74, 1, 62, 2, 23, 2, 58, 1, 54
#
# Sofia, Bennet
# , 3, 64, 3, 85, 3, 58, 2, 79, 3, 40, 4, 4, 1, 31
#
# Frankie, Reed
# , 4, 94, 3, 69, 1, 61, 3, 86, 2, 28, 4, 50
#
# Daniel, Reed
# , 2, 72, 2, 74, 3, 15, 2, 71, 4, 86, 2, 93, 1, 61, 3, 53
#
# Isabelle, Sanchez
# , 2, 25, 3, 7, 1, 91, 2, 70, 3, 16, 4, 77
#
# Teddy, Robinson
# , 3, 84, 4, 63, 1, 45
#
# Jacob, Parker
# , 1, 92, 2, 87, 4, 99, 1, 6, 4, 76, 3, 98, 1, 18
#
# Alexander, Thompson
# , 3, 50, 3, 88, 4, 98, 4, 7, 1, 33, 1, 4
#
# Henry, Rodriguez
# , 4, 47, 4, 44, 2, 34, 1, 32, 3, 43, 2, 55
#
# Stanley, Ramirez
# , 2, 94, 3, 55, 2, 69
#
# Maria, Carter
# , 3, 44, 3, 19, 3, 76, 3, 16, 1, 50, 3, 2, 2, 63, 1, 89
#
# Ruby, Moore
# , 4, 48, 4, 24, 1, 61, 1, 95, 4, 94, 4, 59
#
# Louis, Evans
# , 2, 2, 4, 47, 3, 39, 2, 96, 2, 45, 4, 9, 4, 0
#
# Noah, Howard
# , 2, 16, 3, 36, 2, 87, 3, 47, 2, 32, 2, 98, 1, 20, 1, 59
#
# Isabelle, Long
# , 4, 56, 3, 100, 3, 79, 3, 97, 1, 32, 1, 7
#
# Emilia, Roberts
# , 4, 37, 1, 63, 2, 37, 3, 46, 3, 54
#
# Ada, Kelly
# , 4, 20, 3, 65, 2, 9, 3, 47, 3, 92, 2, 52, 4, 21, 4, 48
#
# Olivia, Reed
# , 2, 80, 2, 92, 3, 100, 2, 69, 2, 29, 4, 60
#
# Jenson, Ramirez
# , 4, 76, 3, 6, 1, 76, 4, 73, 3, 46
#
# Theodore, Ramirez
# , 1, 16, 4, 83, 4, 17, 4, 82
#
# Robyn, Miller
# , 2, 71, 2, 89, 2, 87, 3, 100, 3, 77, 3, 54, 2, 86, 2, 89
#
# Maria, Watson
# , 3, 65, 4, 32, 1, 61, 3, 18, 3, 96, 3, 91, 4, 59
#
# Freya, Thomas
# , 3, 84, 2, 78, 3, 40, 1, 6, 2, 12
#
# Mabel, Gutierrez
# , 3, 7, 1, 20, 3, 90, 4, 78, 3, 42, 4, 27
#
# David, King
# , 3, 67, 4, 12, 4, 29, 2, 34, 3, 35, 1, 75
#
# William, Roberts
# , 1, 67, 2, 8, 1, 2, 2, 65, 4, 3, 2, 90, 1, 36
#
# Harriet, Thomas
# , 1, 24, 3, 20, 3, 70, 4, 22
#
# Elizabeth, Moore
# , 1, 61, 4, 46, 1, 11
#
# Summer, Wilson
# , 3, 6, 3, 4, 1, 12
#
# Harrison, Gutierrez
# , 2, 0, 4, 4, 1, 55, 1, 40, 2, 70
#
# Lucy, Carter
# , 4, 59, 3, 47, 3, 24
#
# Michael, Campbell
# , 2, 68, 4, 57, 3, 71, 4, 99, 4, 8
#
# Phoebe, Rivera
# , 3, 5, 2, 42, 3, 89, 1, 41, 1, 62, 4, 12, 4, 17
#
# Jayden, Kelly
# , 2, 63, 3, 78, 1, 99
#
# Eden, Castillo
# , 3, 75, 4, 77, 1, 2, 1, 73, 4, 69, 3, 10, 3, 44, 3, 70
#
# Benjamin, Gonzales
# , 4, 90, 1, 21, 3, 27
#
# Thomas, Campbell
# , 2, 68, 2, 49, 4, 50
#
# Benjamin, Ruiz
# , 1, 57, 1, 29, 2, 48, 2, 0, 1, 1, 3, 57, 4, 37
#
# Maryam, Gomez
# , 4, 99, 1, 100, 4, 0, 2, 34, 2, 64, 2, 82, 3, 90, 2, 100
#
# Emma, Ortiz
# , 2, 65, 2, 63, 3, 73, 2, 26, 1, 44, 2, 13
#
# Mason, Chavez
# , 4, 66, 3, 91, 4, 14, 1, 7, 3, 25, 4, 29
#
# Rowan, Campbell
# , 4, 6, 2, 11, 2, 87, 4, 97, 3, 62, 4, 88
#
# Milo, Lopez
# , 1, 14, 2, 61, 4, 22, 4, 2, 1, 92
#
# Millie, Smith
# , 3, 12, 3, 3, 2, 94, 3, 66
#
# Eden, Harris
# , 4, 6, 1, 63, 3, 78, 1, 91, 3, 89, 4, 81, 1, 26
#
# Evie, Bennet
# , 2, 42, 1, 72, 4, 62, 2, 6, 1, 50, 4, 20, 4, 37
#
# Hudson, Cox
# , 1, 9, 2, 97, 2, 90, 3, 77, 4, 93, 4, 89
#
# Isabella, Murphy
# , 3, 13, 1, 22, 1, 68, 2, 65, 4, 78, 4, 7
#
# Sebastian, Gonzales
# , 4, 27, 1, 83, 4, 48
#
# Jaxon, Ruiz
# , 3, 86, 2, 21, 2, 15, 2, 71, 1, 66, 4, 13, 2, 69, 3, 62
#
# Arabella, Wood
# , 4, 64, 2, 80, 1, 83
#
# Penelope, James
# , 2, 44, 4, 22, 2, 94, 3, 83
#
# Grace, King
# , 4, 49, 1, 82, 4, 83, 2, 66
#
# Eden, Young
# , 4, 91, 1, 43, 4, 74, 2, 83
#
# Sofia, Gray
# , 3, 97, 2, 60, 3, 5, 3, 39, 4, 3
#
# Jack, Murphy
# , 1, 14, 2, 93, 1, 25, 1, 74, 1, 65, 3, 16
#
# Mohammad, Adams
# , 1, 23, 3, 13, 3, 79, 3, 82, 3, 52, 3, 99, 3, 33
#
# Elsie, Davis
# , 4, 44, 1, 29, 1, 62, 4, 63, 3, 44, 3, 45, 2, 59
#
# Matilda, Myers
# , 4, 58, 2, 50, 4, 28, 1, 4, 3, 91, 3, 51, 3, 94
#
# Arlo, Miller
# , 4, 70, 4, 77, 1, 43, 2, 25, 4, 29, 3, 81
#
# Joshua, Robinson
# , 1, 81, 4, 55, 2, 66, 3, 60
#
# Daniel, Lee
# , 4, 75, 3, 36, 1, 16, 4, 75, 4, 69, 2, 34, 2, 34
#
# Harley, Nguyen
# , 2, 31, 3, 2, 1, 86, 1, 79, 1, 55, 3, 96, 2, 7, 1, 85
#
# Ronnie, Peterson
# , 3, 63, 3, 37, 4, 3, 3, 65, 4, 31
#
# Elijah, Brown
# , 1, 8, 1, 93, 1, 6, 2, 31, 2, 5, 4, 3
#
# Willow, Reed
# , 1, 86, 4, 99, 2, 0, 3, 97
#
# Millie, Allen
# , 2, 10, 4, 70, 3, 78, 3, 6, 4, 86
#
# Ibrahim, Martinez
# , 1, 73, 3, 44, 2, 83, 3, 13
#
# Toby, White
# , 3, 6, 1, 21, 3, 51, 3, 93, 4, 73, 1, 81
#
# Elodie, Williams
# , 2, 22, 1, 85, 2, 89, 2, 72, 2, 49, 1, 15
#
# Carter, Gomez
# , 1, 46, 2, 74, 3, 59, 1, 79, 2, 62, 2, 19, 1, 93, 3, 22
#
# Grace, Mitchell
# , 4, 53, 3, 49, 3, 96, 3, 6, 3, 30, 2, 77
#
# Evie, Johnson
# , 1, 26, 1, 99, 3, 85
#
# Edith, Wright
# , 2, 2, 4, 50, 2, 54, 4, 51, 3, 85, 3, 30, 3, 100, 2, 52
#
# Esme, Howard
# , 2, 97, 4, 17, 2, 35, 4, 77, 4, 59
#
# Erin, Brooks
# , 4, 99, 3, 21, 2, 24
#
# Milo, Kelly
# , 1, 70, 3, 2, 4, 19, 1, 80, 1, 64
#
# Joshua, Myers
# , 4, 61, 4, 9, 2, 58
#
# Reuben, Howard
# , 3, 53, 2, 63, 3, 75, 1, 17, 3, 31, 4, 76
#
# Isaac, Murphy
# , 4, 33, 3, 51, 2, 77, 3, 77, 4, 42
#
# Louis, Campbell
# , 2, 3, 2, 33, 4, 38, 4, 24, 3, 79
#
# Finn, Roberts
# , 4, 36, 3, 68, 1, 42
#
# Lilly, Davis
# , 3, 57, 4, 44, 1, 48, 2, 21, 2, 56, 1, 18, 4, 98, 2, 74
#
# Ivy, Allen
# , 2, 66, 2, 49, 2, 67, 3, 40, 3, 31, 1, 38
#
# Clara, Lewis
# , 4, 63, 1, 20, 1, 76, 3, 55, 2, 5, 3, 59, 2, 94
#
# Ellie, Wright
# , 2, 60, 1, 100, 2, 79, 2, 14, 1, 96, 4, 31
#
# Eleanor, Perez
# , 1, 66, 3, 40, 3, 80
#
# Lilly, Edwards
# , 4, 30, 3, 87, 3, 83, 1, 64
#
# Poppy, Taylor
# , 2, 79, 1, 9, 4, 72
#
# Deliah, Walker
# , 1, 1, 4, 66, 4, 0, 3, 100, 4, 31, 1, 0
#
# Michael, Moore
# , 4, 2, 1, 43, 4, 22, 1, 9
#
# Dylan, Williams
# , 4, 57, 3, 58, 3, 39, 2, 0, 1, 69, 4, 0
#
# William, Sanchez
# , 4, 17, 2, 65, 3, 44
#
# Ava, Bennet
# , 4, 23, 1, 22, 3, 55, 4, 11
#
# Jackson, Gutierrez
# , 1, 70, 2, 95, 1, 28
#
# Lyra, Thomas
# , 3, 84, 1, 99, 1, 11, 4, 28, 4, 89, 3, 69
#
# Elijah, Wright
# , 3, 65, 2, 23, 3, 87
#
# Oliver, Clark
# , 3, 16, 2, 57, 3, 78
#
# Lottie, Morales
# , 3, 57, 3, 7, 2, 48
#
# Chester, Edwards
# , 1, 37, 4, 51, 3, 25, 3, 97, 3, 49
#
# Muhammad, Rivera
# , 4, 12, 4, 91, 3, 7, 3, 61, 4, 60
#
# Eleanor, Cox
# , 3, 55, 1, 14, 3, 24
#
# Poppy, Hughes
# , 1, 99, 1, 27, 4, 26
#
# Evelyn, Stewart
# , 3, 86, 3, 4, 2, 50, 2, 31, 2, 86, 3, 53, 4, 15, 1, 65
#
# Ivy, Castillo
# , 3, 93, 1, 86, 2, 50
#
# Leo, Cruz
# , 2, 80, 2, 23, 1, 91
#
# Eva, Edwards
# , 3, 10, 2, 63, 2, 94, 3, 73, 2, 63, 4, 46, 4, 23, 3, 100
#
# Isaac, Harris
# , 4, 79, 2, 65, 3, 5, 3, 74, 2, 90, 3, 72, 2, 26
#
# Mila, Campbell
# , 4, 100, 4, 35, 1, 84, 3, 98, 1, 4, 4, 7, 2, 77, 1, 66
#
# Noah, Foster
# , 2, 42, 2, 11, 3, 1, 2, 33, 4, 63, 1, 53, 2, 77
#
# Penelope, Wright
# , 4, 67, 3, 91, 4, 56, 4, 29, 3, 40, 1, 41, 1, 41, 3, 3
#
# Finn, Kelly
# , 4, 66, 4, 71, 4, 90, 2, 100, 3, 100
#
# Freya, Castillo
# , 1, 84, 1, 15, 1, 13, 1, 26, 3, 78, 2, 60, 3, 48
#
# Robyn, Nelson
# , 4, 38, 2, 4, 2, 79, 2, 21, 4, 42, 4, 21
#
# Jesse, Garcia
# , 2, 41, 2, 49, 3, 42, 3, 37
#
# Freddie, Sanchez
# , 4, 76, 2, 47, 3, 28, 3, 74, 1, 93
#
# Elodie, Long
# , 4, 10, 4, 48, 1, 71, 3, 94, 3, 89
#
# Thomas, Johnson
# , 3, 78, 4, 44, 4, 72
#
# Rowan, Adams
# , 1, 83, 2, 13, 3, 34, 4, 16, 3, 5, 4, 45, 4, 22, 2, 56
#
# Clara, Patel
# , 1, 67, 3, 76, 1, 70
#
# Elliott, Jimenez
# , 1, 57, 4, 73, 1, 15, 4, 100, 2, 67
#
# Molly, Murphy
# , 3, 72, 4, 58, 1, 85, 4, 77, 2, 77
#
# Jasper, Ramirez
# , 2, 51, 1, 30, 3, 34
#
# Alexander, Roberts
# , 3, 26, 1, 50, 4, 98, 1, 13, 4, 30, 1, 89, 4, 93, 3, 51
#
# Harvey, Clark
# , 3, 83, 1, 83, 1, 62, 3, 29, 3, 53, 3, 16, 3, 29, 2, 7
#
# Myla, Kim
# , 3, 0, 4, 48, 3, 47, 3, 59, 4, 17
#
# Louis, Edwards
# , 2, 100, 4, 33, 2, 45, 4, 27, 2, 14
#
# Daisy, Green
# , 4, 39, 3, 38, 3, 47, 4, 17, 2, 11, 2, 3
#
# Rose, Sanchez
# , 2, 33, 3, 42, 4, 60, 4, 32
#
# Evelyn, Bailey
# , 3, 64, 2, 5, 3, 29, 2, 29
#
# Ellis, Cox
# , 4, 29, 3, 84, 1, 92, 2, 85
#
# Elliott, Howard
# , 2, 30, 3, 35, 2, 88, 1, 27
#
# Max, Martinez
# , 4, 25, 3, 38, 3, 37, 2, 69, 2, 5
#
# Olive, Ortiz
# , 3, 40, 1, 68, 3, 48, 4, 38
#
# Arthur, Hughes
# , 1, 17, 1, 11, 4, 6, 4, 83, 2, 43
#
# Alfred, Ortiz
# , 3, 91, 2, 6, 2, 41, 1, 21
#
# Ava, Jackson
# , 2, 43, 4, 39, 3, 11, 4, 58, 2, 98
